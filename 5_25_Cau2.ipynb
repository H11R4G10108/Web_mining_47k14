# %%
import nltk
import os
from nltk.probability import FreqDist
data=''
directory = 'D:\Data_Preprocessing'
txt_files = [f for f in os.listdir(directory) if f.endswith('.txt')]
for file in txt_files:
    filename=os.path.join('D:\Data_Preprocessing', file)    
    with open(filename, 'r',encoding='utf-8') as f:         
            line=f.read()
    data+=line+','
# reading the file 
# splitting the text it further when '.' is seen. 
data_into_list = data.split(",") 
# Compute the frequency of all words
frequency_dist = FreqDist(word.lower() for word in data_into_list)
## Consider words with length greater than 3 and plot
large_words = dict([(k,v) for k,v in frequency_dist.items() if len(k)>3])
frequency_dist = nltk.FreqDist(large_words)
frequency_dist.plot(50,cumulative=False)
from wordcloud import WordCloud
wcloud = WordCloud().generate_from_frequencies(frequency_dist)
#plotting the wordcloud
import matplotlib.pyplot as plt
plt.imshow(wcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
